# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
da=sns.load_dataset("titanic")
da
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# multivariate --->scatterplot 
x=numerical y= numerical hue = categorical

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['pclass'],hue=da['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['age'],hue=da['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['sibsp'],hue=da['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['parch'],hue=da['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['fare'],hue=da['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['pclass'],y=da['age'],hue=da['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['pclass'],y=da['sibsp'],hue=da['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['pclass'],y=da['parch'],hue=da['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['pclass'],y=da['fare'],hue=da['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['age'],y=da['sibsp'],hue=da['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['age'],y=da['parch'],hue=da['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['age'],y=da['fare'],hue=da['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['sibsp'],y=da['parch'],hue=da['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['sibsp'],y=da['fare'],hue=da['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['parch'],y=da['fare'],hue=da['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['pclass'],hue=da['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['age'],hue=da['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['sibsp'],hue=da['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['parch'],hue=da['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['fare'],hue=da['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['pclass'],y=da['age'],hue=da['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['pclass'],y=da['sibsp'],hue=da['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['pclass'],y=da['parch'],hue=da['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['pclass'],y=da['fare'],hue=da['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['age'],y=da['sibsp'],hue=da['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['age'],y=da['parch'],hue=da['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['age'],y=da['fare'],hue=da['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['sibsp'],y=da['parch'],hue=da['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['sibsp'],y=da['fare'],hue=da['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['parch'],y=da['fare'],hue=da['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['pclass'],hue=da['class'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['age'],hue=da['class'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['sibsp'],hue=da['class'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['parch'],hue=da['class'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['fare'],hue=da['class'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['pclass'],y=da['age'],hue=da['class'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['pclass'],y=da['sibsp'],hue=da['class'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['pclass'],y=da['parch'],hue=da['class'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['pclass'],y=da['fare'],hue=da['class'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['age'],y=da['sibsp'],hue=da['class'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['age'],y=da['parch'],hue=da['class'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['age'],y=da['fare'],hue=da['class'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['sibsp'],y=da['parch'],hue=da['class'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['sibsp'],y=da['fare'],hue=da['class'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['parch'],y=da['fare'],hue=da['class'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['pclass'],hue=da['who'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['age'],hue=da['who'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['sibsp'],hue=da['who'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['parch'],hue=da['who'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['fare'],hue=da['who'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['pclass'],y=da['age'],hue=da['who'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['pclass'],y=da['sibsp'],hue=da['who'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['pclass'],y=da['parch'],hue=da['who'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['pclass'],y=da['fare'],hue=da['who'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['age'],y=da['sibsp'],hue=da['who'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['age'],y=da['parch'],hue=da['who'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['age'],y=da['fare'],hue=da['who'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['sibsp'],y=da['parch'],hue=da['who'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['sibsp'],y=da['fare'],hue=da['who'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['parch'],y=da['fare'],hue=da['who'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['pclass'],hue=da['deck'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['age'],hue=da['deck'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['sibsp'],hue=da['deck'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['parch'],hue=da['deck'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['fare'],hue=da['deck'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['pclass'],y=da['age'],hue=da['deck'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['pclass'],y=da['sibsp'],hue=da['deck'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['pclass'],y=da['parch'],hue=da['deck'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['pclass'],y=da['fare'],hue=da['deck'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['age'],y=da['sibsp'],hue=da['deck'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['age'],y=da['parch'],hue=da['deck'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['age'],y=da['fare'],hue=da['deck'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['sibsp'],y=da['parch'],hue=da['deck'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['sibsp'],y=da['fare'],hue=da['deck'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['parch'],y=da['fare'],hue=da['deck'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['pclass'],hue=da['embark_town'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['age'],hue=da['embark_town'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['sibsp'],hue=da['embark_town'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['parch'],hue=da['embark_town'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['fare'],hue=da['embark_town'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['pclass'],y=da['age'],hue=da['embark_town'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['pclass'],y=da['sibsp'],hue=da['embark_town'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['pclass'],y=da['parch'],hue=da['embark_town'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['pclass'],y=da['fare'],hue=da['embark_town'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['age'],y=da['sibsp'],hue=da['embark_town'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['age'],y=da['parch'],hue=da['embark_town'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['age'],y=da['fare'],hue=da['embark_town'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['sibsp'],y=da['parch'],hue=da['embark_town'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['sibsp'],y=da['fare'],hue=da['embark_town'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['parch'],y=da['fare'],hue=da['embark_town'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['pclass'],hue=da['alive'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['age'],hue=da['alive'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['sibsp'],hue=da['alive'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['parch'],hue=da['alive'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['survived'],y=da['fare'],hue=da['alive'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['pclass'],y=da['age'],hue=da['alive'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['pclass'],y=da['sibsp'],hue=da['alive'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['pclass'],y=da['parch'],hue=da['alive'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['pclass'],y=da['fare'],hue=da['alive'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['age'],y=da['sibsp'],hue=da['alive'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['age'],y=da['parch'],hue=da['alive'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['age'],y=da['fare'],hue=da['alive'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['sibsp'],y=da['parch'],hue=da['alive'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['sibsp'],y=da['fare'],hue=da['alive'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=da['parch'],y=da['fare'],hue=da['alive'])
plt.show()

# %%
# multivariate barplot
x= numerical , y= categorical , hue= categorical

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['sex'],hue=da['embarked'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['sex'],hue=da['class'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['sex'],hue=da['who'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['sex'],hue=da['adult_male'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['sex'],hue=da['deck'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['sex'],hue=da['embark_town'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['sex'],hue=da['alive'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['sex'],hue=da['alone'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['embarked'],hue=da['class'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['embarked'],hue=da['who'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['embarked'],hue=da['adult_male'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['embarked'],hue=da['deck'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['embarked'],hue=da['embark_town'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['embarked'],hue=da['alive'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['embarked'],hue=da['alone'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['class'],hue=da['who'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['class'],hue=da['adult_male'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['class'],hue=da['deck'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['class'],hue=da['embark_town'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['class'],hue=da['alive'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['class'],hue=da['alone'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['who'],hue=da['adult_male'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['who'],hue=da['deck'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['who'],hue=da['embark_town'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['who'],hue=da['alive'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['who'],hue=da['alone'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['adult_male'],hue=da['deck'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['adult_male'],hue=da['embark_town'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['adult_male'],hue=da['alive'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['adult_male'],hue=da['alone'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['deck'],hue=da['embark_town'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['deck'],hue=da['alive'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['deck'],hue=da['alone'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['embark_town'],hue=da['alive'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['embark_town'],hue=da['alone'],dodge=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=da['survived'],y=da['alive'],hue=da['alone'],dodge=True)
plt.show()
